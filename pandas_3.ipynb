# %%
import pandas as pd

# Lendo o arquivo Excel
caminho = r"C:\Users\FARIAS\Desktop\ff projetos 2701 - Copia\Rastreamento F&F BA EM AJUSTE 2.xlsx"
aba = "F&F BA" 
df_tabelao = pd.read_excel(caminho, sheet_name=aba, engine="openpyxl")

# Filtrando o DataFrame
df_filtrado = df_tabelao.loc[df_tabelao['Data Documento de Transporte'].notna()]

# Preenchendo valores NaN na coluna 'Canal' com 'farma'
df_filtrado['Canal'].fillna('farma', inplace=True)

# Criando a coluna 'Valor Produto'
df_filtrado['Valor Produto'] = df_filtrado["Volume"] * df_filtrado["Valor"]

# Exibindo o DataFrame com a nova coluna
display(df_filtrado)

# Mesclando a nova coluna 'Valor Produto' ao DataFrame original
# df_final = pd.merge(df_tabelao, df_filtrado[['Chave Primária', 'Valor Produto']], on='Chave Primária')

# Exibindo o DataFrame final
display(df_filtrado)
# Out:
# C:\Users\FARIAS\AppData\Local\Temp\ipykernel_14400\1520262661.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado['Canal'].fillna('farma', inplace=True)
# C:\Users\FARIAS\AppData\Local\Temp\ipykernel_14400\1520262661.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado['Valor Produto'] = df_filtrado["Volume"] * df_filtrado["Valor"]
#       Quant      Mês Origem  Transportadora      NF  Volume    Valor  \
# 32       33  JANEIRO     BA  CLAUDIO DONATO  337988       1  1007.95
# ...
